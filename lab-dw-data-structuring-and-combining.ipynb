# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
# Your code goes here

import pandas as pd

url1 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv"
url2 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv"
url3 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv"

df1 = pd.read_csv(url1)
df2 = pd.read_csv(url2)
df3 = pd.read_csv(url3)

# %%
print(list(df1.columns))
print(list(df2.columns))
print(list(df3.columns))

#set all the columns to the same format

df1.columns = list(map(lambda x : x.lower().replace(" ","_"), df1.columns))
df2.columns = list(map(lambda x : x.lower().replace(" ","_"), df2.columns))
df3.columns = list(map(lambda x : x.lower().replace(" ","_"), df3.columns))

#rename column ST to state

df1.rename(columns={"st":"state"}, inplace=True)
df2.rename(columns={"st":"state"}, inplace=True)
# Out:
# ['customer', 'st', 'gender', 'education', 'customer_lifetime_value', 'income', 'monthly_premium_auto', 'number_of_open_complaints', 'policy_type', 'vehicle_class', 'total_claim_amount']
# ['customer', 'st', 'gender', 'education', 'customer_lifetime_value', 'income', 'monthly_premium_auto', 'number_of_open_complaints', 'total_claim_amount', 'policy_type', 'vehicle_class']
# ['customer', 'state', 'customer_lifetime_value', 'education', 'gender', 'income', 'monthly_premium_auto', 'number_of_open_complaints', 'policy_type', 'total_claim_amount', 'vehicle_class']

# %%
print(list(df1.columns))
print(list(df2.columns))
print(list(df3.columns))
# Out:
# ['customer', 'state', 'gender', 'education', 'customer_lifetime_value', 'income', 'monthly_premium_auto', 'number_of_open_complaints', 'policy_type', 'vehicle_class', 'total_claim_amount']
# ['customer', 'state', 'gender', 'education', 'customer_lifetime_value', 'income', 'monthly_premium_auto', 'number_of_open_complaints', 'total_claim_amount', 'policy_type', 'vehicle_class']
# ['customer', 'state', 'customer_lifetime_value', 'education', 'gender', 'income', 'monthly_premium_auto', 'number_of_open_complaints', 'policy_type', 'total_claim_amount', 'vehicle_class']

# %%
#Combining the three datasets

mydf = pd.concat([df1,df2,df3])
mydf
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
# Your code goes here
import pandas as pd
url = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv"
df = pd.read_csv(url)

# %%
(x,y) = df.shape
print(f"The df has {x} rows and {y} columns.")
# Out:
# The df has 10910 rows and 27 columns.

# %%
df.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type', 'month'],
#       dtype='object')

# %%
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. 
#Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.
pivot_df = df.pivot_table(columns='sales_channel',values='total_claim_amount',aggfunc='sum').round(2)
pivot_df
# Out:
# sales_channel            Agent     Branch  Call Center        Web
# total_claim_amount  1810226.82  1301204.0    926600.82  706600.04

# %%
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. 
# Analyze the resulting table to draw insights.
pivot_df2 = df.pivot_table(index = "gender",columns='education',values='total_claim_amount',aggfunc='mean')
pivot_df2

#Total claim amount is higher for M than for F. 
#Total claim amount is lower for Master and Doctors.
# Out:
# education    Bachelor     College      Doctor  High School or Below  \
# gender
# F          415.083016  389.436584  332.498824            459.650066
# M          440.472063  458.548390  341.660257            519.500247
#
# education      Master
# gender
# F          349.908049
# M          359.090827

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
pivot_df3 = df.pivot_table(index = "policy_type",columns='month',values='number_of_open_complaints',aggfunc='sum',margins=True,margins_name='Total')
pivot_df3
# Out:
# month                     1            2        Total
# policy_type
# Corporate Auto   443.434952   385.208135   828.643087
# Personal Auto   1727.605722  1453.684441  3181.290162
# Special Auto      87.074049    95.226817   182.300866
# Total           2258.114722  1934.119393  4192.234115

# %%
# Aggregate the values before melting
#agg_data = df.groupby(['policy_type', 'month', 'number_of_open_complaints']).sum().reset_index()
#agg_data
# Out:
# /var/folders/g4/xn5x8vvs1wn45zdrg3yft5bw0000gn/T/ipykernel_16742/3555142719.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   agg_data = df.groupby(['policy_type', 'month', 'number_of_open_complaints']).sum().reset_index()
#        policy_type  month  number_of_open_complaints  unnamed:_0  \
# 0   Corporate Auto      1                   0.000000     5037748
# 1   Corporate Auto      1                   0.384256      386940
# 2   Corporate Auto      1                   1.000000      790204
# 3   Corporate Auto      1                   2.000000      191298
# 4   Corporate Auto      1                   3.000000      226248
# 5   Corporate Auto      1                   4.000000       48905
# 6   Corporate Auto      1                   5.000000       51015
# ...

# %%
# Melt the DataFrame, keeping 'policy_type' and 'month' as identifier variables, and 'number_of_open_complaints' as value variables
melted_data = pd.melt(df, id_vars=['policy_type', 'month'], value_vars=['number_of_open_complaints'],var_name='Indicator', value_name='Value')
melted_data
# Out:
#           policy_type  month                  Indicator     Value
# 0      Corporate Auto      2  number_of_open_complaints  0.000000
# 1       Personal Auto      1  number_of_open_complaints  0.000000
# 2       Personal Auto      2  number_of_open_complaints  0.000000
# 3      Corporate Auto      1  number_of_open_complaints  0.000000
# 4       Personal Auto      1  number_of_open_complaints  0.384256
# ...               ...    ...                        ...       ...
# 10905   Personal Auto      1  number_of_open_complaints  0.384256
# 10906   Personal Auto      1  number_of_open_complaints  0.000000
# 10907  Corporate Auto      2  number_of_open_complaints  0.000000
# 10908   Personal Auto      2  number_of_open_complaints  4.000000
# 10909   Personal Auto      1  number_of_open_complaints  0.000000
#
# [10910 rows x 4 columns]
